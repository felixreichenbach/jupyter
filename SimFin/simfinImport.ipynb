# %%
# !pip3 install simfin

import simfin as sf

# Set your API-key for downloading data. This key gets the free data.
sf.set_api_key('free')

# Set the local directory where data-files are stored.
# The directory will be created if it does not already exist.
sf.set_data_dir('~/simfin_data/')

# Download the data from the SimFin server and load into a Pandas DataFrame.
df = sf.load_income(variant='annual', market='us')

# Print the first rows of the data.
print(df.head())

#Remove dot in column name
cleanDF = df.rename(columns={'Pretax Income (Loss), Adj.':'Pretax Income (Loss), Adj'})

#Convert dataframe to list of dictionaries
finList =  cleanDF.apply(lambda x : x.dropna().to_dict(),axis=1).tolist()

# %%
# !pip3 install pymongo[srv]

import pymongo

#Open connection to MongoDB
client = pymongo.MongoClient("mongodb+srv://user:password@hostname.mongodb.net/test?retryWrites=true&w=majority")

#Get database "simfin"
db = client.simfin

#Insert the list of dictionaries into the "simfin" database "ticker" collection
result = db.ticker.insert_many(finList)

print(result)
